# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd

df = pd.read_csv(
    "/mnt/c/Users/manav/OneDrive/Desktop/paitent health/Patient_Health_Records_Cleaned.csv"
)

print(df.head())
# Out:
#     Age  Gender         City   BMI  Heart_Rate  Cholesterol_Level  Diabetic  \
# 0  48.0       0       Boston  22.5        83.0              190.0         0
# 1  48.0       0     New York  25.8        87.0              190.0         0
# 2  48.0       0     New York  22.5        87.0              190.0         0
# 3  80.0       0     New York  33.4        87.0              250.0         1
# 4  48.0       1  Los Angeles  30.1        87.0              190.0         0
#
#    Smoker         Medications  Follow_Up Diagnosis_Code Has_Disease  \
# 0       1             Unknown       30.0            A00           0
# 1       0             Unknown       14.0        Unknown     Unknown
# 2       1  Aspirin; Metformin       30.0            B20     Unknown
# 3       1             Unknown       30.0        Unknown     Unknown
# 4       0             Unknown       14.0            I10           1
#
#    Systolic_BP  Diastolic_BP
# 0        120.0          80.0
# 1        120.0          80.0
# 2        120.0          80.0
# 3        120.0          80.0
# 4        120.0          80.0

# %%
df_ml = df.copy()

# %%
df_ml.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9494 entries, 0 to 9493
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Age                9494 non-null   float64
#  1   Gender             9494 non-null   int64
#  2   City               9494 non-null   str
#  3   BMI                9494 non-null   float64
#  4   Heart_Rate         9494 non-null   float64
#  5   Cholesterol_Level  9494 non-null   float64
#  6   Diabetic           9494 non-null   int64
#  7   Smoker             9494 non-null   int64
#  8   Medications        9494 non-null   str
#  9   Follow_Up          9494 non-null   float64
#  10  Diagnosis_Code     9494 non-null   str
#  11  Has_Disease        9494 non-null   str
#  12  Systolic_BP        9494 non-null   float64
#  13  Diastolic_BP       9494 non-null   float64
# dtypes: float64(7), int64(3), str(4)
# memory usage: 1.0 MB

# %%
df_ml.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
X = df_ml.drop('Has_Disease', axis=1)
y = df_ml['Has_Disease']

# %%
print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (9494, 13)
# y shape: (9494,)

# %%
X = df_ml.drop('Has_Disease', axis=1)
y = df_ml['Has_Disease']

# %%
print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (9494, 13)
# y shape: (9494,)

# %%
print(df_ml.shape)
print(df_ml.columns.tolist())
# Out:
# (9494, 14)
# ['Age', 'Gender', 'City', 'BMI', 'Heart_Rate', 'Cholesterol_Level', 'Diabetic', 'Smoker', 'Medications', 'Follow_Up', 'Diagnosis_Code', 'Has_Disease', 'Systolic_BP', 'Diastolic_BP']

# %%
df_ml = df.copy()

# Standardize target
df_ml['Has_Disease'] = df_ml['Has_Disease'].replace({
    'unknown': 'Unknown'
})

# Remove rows where the target is unknown
df_ml = df_ml[df_ml['Has_Disease'] != 'Unknown'].copy()

print(df_ml.shape)
# Out:
# (4810, 14)

# %%
df_ml = pd.get_dummies(
    df_ml,
    columns=['City', 'Medications', 'Diagnosis_Code'],
    dtype=int
)

# %%
df_ml['Has_Disease'] = pd.to_numeric(
    df_ml['Has_Disease']
).astype(int)

# %%
print(df_ml.shape)
print(df_ml.dtypes)
# Out:
# (4810, 24)
# Age                                  float64
# Gender                                 int64
# BMI                                  float64
# Heart_Rate                           float64
# Cholesterol_Level                    float64
# Diabetic                               int64
# Smoker                                 int64
# Follow_Up                            float64
# Has_Disease                            int64
# Systolic_BP                          float64
# Diastolic_BP                         float64
# City_Boston                            int64
# City_Chicago                           int64
# City_Los Angeles                       int64
# City_New York                          int64
# City_Unknown                           int64
# Medications_Aspirin; Metformin         int64
# Medications_Lisinopril; Metformin      int64
# Medications_Unknown                    int64
# Diagnosis_Code_A00                     int64
# Diagnosis_Code_B20                     int64
# Diagnosis_Code_E11.9                   int64
# Diagnosis_Code_I10                     int64
# Diagnosis_Code_Unknown                 int64
# dtype: object

# %%
X = df_ml.drop('Has_Disease', axis=1)
y = df_ml['Has_Disease']

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (4810, 23)
# y shape: (4810,)

# %%
# %pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /home/manav/miniconda3/lib/python3.14/site-packages (1.9.0)
# Requirement already satisfied: numpy>=1.24.1 in /home/manav/miniconda3/lib/python3.14/site-packages (from scikit-learn) (2.5.3)
# Requirement already satisfied: scipy>=1.10.0 in /home/manav/miniconda3/lib/python3.14/site-packages (from scikit-learn) (1.18.1)
# Requirement already satisfied: joblib>=1.4.0 in /home/manav/miniconda3/lib/python3.14/site-packages (from scikit-learn) (1.6.0)
# Requirement already satisfied: narwhals>=2.0.1 in /home/manav/miniconda3/lib/python3.14/site-packages (from scikit-learn) (2.26.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /home/manav/miniconda3/lib/python3.14/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: cloudpickle>=3.0 in /home/manav/miniconda3/lib/python3.14/site-packages (from joblib>=1.4.0->scikit-learn) (3.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Features (everything except the target)
X = df_ml.drop('Has_Disease', axis=1)

# Target (what we want to predict)
y = df_ml['Has_Disease']

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (4810, 23)
# y shape: (4810,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training data:", X_train.shape)
print("Testing data:", X_test.shape)
# Out:
# Training data: (3848, 23)
# Testing data: (962, 23)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

model = Pipeline([
    ('scaler', StandardScaler()),
    ('classifier', LogisticRegression(max_iter=2000))
])

model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('classifier', LogisticRegression(max_iter=2000))])

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", accuracy)
print("Accuracy (%):", accuracy * 100)
# Out:
# Accuracy: 0.4812889812889813
# Accuracy (%): 48.12889812889813

# %%
from sklearn.metrics import classification_report, confusion_matrix

print("Accuracy:", accuracy * 100, "%")

print("\nClassification Report:")
print(classification_report(y_test, y_pred))

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 48.12889812889813 %
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.49      0.56      0.52       485
#            1       0.47      0.40      0.43       477
#
#     accuracy                           0.48       962
#    macro avg       0.48      0.48      0.48       962
# weighted avg       0.48      0.48      0.48       962
#
#
# Confusion Matrix:
# [[272 213]
#  [286 191]]

# %%
from sklearn.metrics import classification_report, confusion_matrix

print("Classification Report:")
print(classification_report(y_test, y_pred))

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.49      0.56      0.52       485
#            1       0.47      0.40      0.43       477
#
#     accuracy                           0.48       962
#    macro avg       0.48      0.48      0.48       962
# weighted avg       0.48      0.48      0.48       962
#
# Confusion Matrix:
# [[272 213]
#  [286 191]]

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /home/manav/miniconda3/lib/python3.14/site-packages (3.4.1)
# Requirement already satisfied: numpy in /home/manav/miniconda3/lib/python3.14/site-packages (from xgboost) (2.5.3)
# Requirement already satisfied: scipy in /home/manav/miniconda3/lib/python3.14/site-packages (from xgboost) (1.18.1)
# Requirement already satisfied: nvidia-nccl-cu13 in /home/manav/miniconda3/lib/python3.14/site-packages (from xgboost) (2.31.2)

# %%
from xgboost import XGBClassifier

xgb_model = XGBClassifier(
    n_estimators=200,
    max_depth=5,
    learning_rate=0.05,
    random_state=42,
    eval_metric='logloss'
)

xgb_model.fit(X_train, y_train)

print("XGBoost model trained successfully!")
# Out:
# XGBoost model trained successfully!

# %%
y_pred_xgb = xgb_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

xgb_accuracy = accuracy_score(y_test, y_pred_xgb)

print("XGBoost Accuracy:", xgb_accuracy)
print("XGBoost Accuracy (%):", xgb_accuracy * 100)
# Out:
# XGBoost Accuracy: 0.47505197505197505
# XGBoost Accuracy (%): 47.50519750519751

# %%
print("Target:")
print(y.value_counts())

print("\nX data types:")
print(X.dtypes)

print("\nMissing values:")
print(X.isnull().sum().sum())
# Out:
# Target:
# Has_Disease
# 0    2424
# 1    2386
# Name: count, dtype: int64
#
# X data types:
# Age                                  float64
# Gender                                 int64
# BMI                                  float64
# Heart_Rate                           float64
# Cholesterol_Level                    float64
# Diabetic                               int64
# Smoker                                 int64
# Follow_Up                            float64
# Systolic_BP                          float64
# Diastolic_BP                         float64
# City_Boston                            int64
# City_Chicago                           int64
# City_Los Angeles                       int64
# City_New York                          int64
# City_Unknown                           int64
# Medications_Aspirin; Metformin         int64
# Medications_Lisinopril; Metformin      int64
# Medications_Unknown                    int64
# Diagnosis_Code_A00                     int64
# Diagnosis_Code_B20                     int64
# Diagnosis_Code_E11.9                   int64
# Diagnosis_Code_I10                     int64
# Diagnosis_Code_Unknown                 int64
# dtype: object
#
# Missing values:
# 0

# %%
print("\nPredicted values:")
print(pd.Series(y_pred_xgb).value_counts())
# Out:
# Predicted values:
# 0    500
# 1    462
# Name: count, dtype: int64
